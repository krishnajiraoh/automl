# %%
#import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from pprint import pprint

import sklearn.datasets
import sklearn.metrics

import autosklearn.classification

# %%
churn_df = pd.read_csv("data/churn_data.csv")
churn_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
X = churn_df.iloc[: , 1:-1]
y = churn_df.iloc[: , -1]

X_train, X_test, y_train, y_test = \
    sklearn.model_selection.train_test_split(X, y, random_state=1)

# %%
## Unable to handle null values

X["TotalCharges"].value_counts()[0:10]
# Out:
#          11
# 20.2     11
# 19.75     9
# 20.05     8
# 19.9      8
# 19.65     8
# 45.3      7
# 19.55     7
# 20.15     6
# 20.25     6
# Name: TotalCharges, dtype: int64

# %%
churn_df["TotalCharges"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <module>
# ----> 1 churn_df["TotalCharges"].astype(float)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:5920, in NDFrame.astype(self, dtype, copy, errors)
#    5913     results = [
#    5914         self.iloc[:, i].astype(dtype, copy=copy)
#    5915         for i in range(len(self.columns))
#    5916     ]
#    5918 else:
#    5919     # else, only a single dtype is given
# -> 5920     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5921     return self._constructor(new_data).__finalize__(self, method="astype")
#    5923 # GH 33113: handle empty frame or series
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/dtypes/cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/dtypes/cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/dtypes/cast.py:1181, in astype_nansafe(arr, dtype, copy, skipna)
#    1177     raise ValueError(msg)
#    1179 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1180     # Explicit copy, or required since NumPy can't view from / to object.
# -> 1181     return arr.astype(dtype, copy=True)
#    1183 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: ''

# %%
automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=120,
    per_run_time_limit=20,
 #   tmp_folder='/tmp/autosklearn_classification_example_tmp',
)
automl.fit(X_train, y_train, dataset_name='churn')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <module>
#       1 automl = autosklearn.classification.AutoSklearnClassifier(
#       2     time_left_for_this_task=120,
#       3     per_run_time_limit=20,
#       4  #   tmp_folder='/tmp/autosklearn_classification_example_tmp',
#       5 )
# ----> 6 automl.fit(X_train, y_train, dataset_name='churn')
#
# File /usr/local/lib/python3.8/dist-packages/autosklearn/estimators.py:1045, in AutoSklearnClassifier.fit(self, X, y, X_test, y_test, feat_type, dataset_name)
#    1042 # remember target type for using in predict_proba later.
#    1043 self.target_type = target_type
# -> 1045 super().fit(
#    1046     X=X,
#    1047     y=y,
#    1048     X_test=X_test,
#    1049     y_test=y_test,
#    1050     feat_type=feat_type,
#    1051     dataset_name=dataset_name,
#    1052 )
#    1054 # After fit, a classifier is expected to define classes_
#    1055 # A list of class labels known to the classifier, mapping each label
#    1056 # to a numerical index used in the model representation our output.
#    1057 self.classes_ = self.automl_.InputValidator.target_validator.classes_
#
# File /usr/local/lib/python3.8/dist-packages/autosklearn/estimators.py:375, in AutoSklearnEstimator.fit(self, **kwargs)
#     373 if self.automl_ is None:
#     374     self.automl_ = self.build_automl()
# --> 375 self.automl_.fit(load_models=self.load_models, **kwargs)
#     377 return self
#
# File /usr/local/lib/python3.8/dist-packages/autosklearn/automl.py:2056, in AutoMLClassifier.fit(self, X, y, X_test, y_test, feat_type, dataset_name, only_return_configuration_space, load_models)
#    2045 def fit(
#    2046     self,
#    2047     X: SUPPORTED_FEAT_TYPES,
#    (...)
#    2054     load_models: bool = True,
#    2055 ):
# -> 2056     return super().fit(
#    2057         X, y,
#    2058         X_test=X_test,
#    2059         y_test=y_test,
#    2060         feat_type=feat_type,
#    2061         dataset_name=dataset_name,
#    2062         only_return_configuration_space=only_return_configuration_space,
#    2063         load_models=load_models,
#    2064         is_classification=True,
#    2065     )
#
# File /usr/local/lib/python3.8/dist-packages/autosklearn/automl.py:639, in AutoML.fit(self, X, y, task, X_test, y_test, feat_type, dataset_name, only_return_configuration_space, load_models, is_classification)
#     631 # Make sure that input is valid
#     632 # Performs Ordinal one hot encoding to the target
#     633 # both for train and test data
#     634 self.InputValidator = InputValidator(
#     635     is_classification=is_classification,
#     636     feat_type=feat_type,
#     637     logger_port=self._logger_port,
#     638 )
# --> 639 self.InputValidator.fit(X_train=X, y_train=y, X_test=X_test, y_test=y_test)
#     640 X, y = self.InputValidator.transform(X, y)
#     642 if X_test is not None:
#
# File /usr/local/lib/python3.8/dist-packages/autosklearn/data/validation.py:146, in InputValidator.fit(self, X_train, y_train, X_test, y_test)
#     139 if X_test is not None and np.shape(X_test)[0] != np.shape(y_test)[0]:
#     140     raise ValueError("Inconsistent number of test datapoints for features and targets,"
#     141                      " {} for features and {} for targets".format(
#     142                          np.shape(X_test)[0],
#     143                          np.shape(y_test)[0],
#     144                      ))
# --> 146 self.feature_validator.fit(X_train, X_test)
#     147 self.target_validator.fit(y_train, y_test)
#     148 self._is_fitted = True
#
# File /usr/local/lib/python3.8/dist-packages/autosklearn/data/feature_validator.py:114, in FeatureValidator.fit(self, X_train, X_test)
#     104         raise ValueError("When providing a DataFrame to Auto-Sklearn, we extract "
#     105                          "the feature types from the DataFrame.dtypes. That is, "
#     106                          "providing the option feat_type to the fit method is not "
#    (...)
#     111                          "https://pandas.pydata.org/pandas-docs/stable/reference"
#     112                          "/api/pandas.DataFrame.astype.html")
#     113     else:
# --> 114         self.feat_type = self.get_feat_type_from_columns(X_train)
#     115 else:
#     116     # Numpy array was provided
#     117     if self.feat_type is None:
#     118         # Assume numerical columns if a numpy array has no feature types
#
# File /usr/local/lib/python3.8/dist-packages/autosklearn/data/feature_validator.py:295, in FeatureValidator.get_feat_type_from_columns(self, X)
#     293 elif not is_numeric_dtype(X[column]):
#     294     if X[column].dtype.name == 'object':
# --> 295         raise ValueError(
#     296             "Input Column {} has invalid type object. "
#     297             "Cast it to a valid dtype before using it in Auto-Sklearn. "
#     298             "Valid types are numerical, categorical or boolean. "
#     299             "You can cast it to a valid dtype using "
#     300             "pandas.Series.astype ."
#     301             "If working with string objects, the following "
#     302             "tutorial illustrates how to work with text data: "
#     303             "https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html".format(  # noqa: E501
#     304                 column,
#     305             )
#     306         )
#     307     elif pd.core.dtypes.common.is_datetime_or_timedelta_dtype(
#     308         X[column].dtype
#     309     ):
#     310         raise ValueError(
#     311             "Auto-sklearn does not support time and/or date datatype as given "
#     312             "in column {}. Please convert the time information to a numerical value "
#    (...)
#     316             )
#     317         )
#
# ValueError: Input Column gender has invalid type object. Cast it to a valid dtype before using it in Auto-Sklearn. Valid types are numerical, categorical or boolean. You can cast it to a valid dtype using pandas.Series.astype .If working with string objects, the following tutorial illustrates how to work with text data: https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
